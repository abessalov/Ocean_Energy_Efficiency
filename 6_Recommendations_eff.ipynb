# %%
# %run startup.py
# Out:
# <style>.container { width:80% !important; }</style>

# %%
plt.style.use('bmh')
# plt.style.use('ggplot')
# plt.style.use('seaborn')
# plt.style.use('default')
# plt.style.use('fivethirtyeight')

# %%
# 1) clean dataset
df = pd.read_csv('data/data_clean.csv')
print(df.shape)
df[:3]
# Out:
# (185039, 28)
#    Property_UPRN Postcode  POST_TOWN  Primary Energy Indicator (kWh/m²/year)  \
# 0     1001100841  EH4 5EZ  EDINBURGH                                  375.00
# 1     1001950838  EH7 4HE  EDINBURGH                                  250.00
# 2     1000995515  EH4 2DL  EDINBURGH                                  403.00
#
#    Total floor area (m²)  Current energy efficiency rating  \
# 0                  94.00                             53.00
# 1                 175.00                             66.00
# 2                  72.00                             61.00
#
#    Potential Energy Efficiency Rating  Current Environmental Impact Rating  \
# 0                               85.00                                45.00
# 1                               80.00                                57.00
# 2                               78.00                                48.00
#
#    Potential Environmental Impact Rating  \
# 0                                  82.00
# 1                                  75.00
# 2                                  64.00
#
#    CO2 Emissions Current Per Floor Area (kg.CO2/m²/yr)  HOT_WATER_ENERGY_EFF  \
# 0                                              66.00                       2
# 1                                              44.00                       4
# 2                                              68.00                       1
#
#    HOT_WATER_ENV_EFF  LIGHTING_DESCRIPTION  Current Emissions (T.CO2/yr)  \
# 0                  2                   100                          6.20
# 1                  4                   100                          7.70
# 2                  2                    50                          4.90
#
#    Potential Reduction in Emissions (T.CO2/yr)  \
# 0                                         4.20
# 1                                         2.80
# 2                                         1.60
#
#    Total current energy costs over 3 years (£)  \
# 0                                     3,789.00
# 1                                     4,635.00
# 2                                     3,570.00
#
#    Current heating costs over 3 years (£)  \
# 0                                2,922.00
# 1                                4,068.00
# 2                                2,226.00
#
#    Potential heating costs over 3 years (£)  \
# 0                                  1,548.00
# 1                                  3,015.00
# 2                                  1,191.00
#
#    Current hot water costs over 3 years (£)  \
# 0                                    645.00
# 1                                    246.00
# 2                                  1,038.00
#
#    Potential hot water costs over 3 years (£)  \
# 0                                      219.00
# 1                                      246.00
# 2                                      564.00
#
#    Current lighting costs over 3 years (£)  \
# 0                                   222.00
# 1                                   321.00
# 2                                   306.00
#
#    Potential lighting costs over 3 years (£)  Part 1 Construction Age Band  \
# 0                                     222.00                      1,949.00
# 1                                     321.00                      1,929.00
# 2                                     207.00                      1,975.00
#
#       Built Form Property Type      dt_day  dt_month    Country
# 0  Semi-Detached         House  2021-01-01         1  EDINBURGH
# 1    End-Terrace         House  2021-01-01         1  EDINBURGH
# 2  Semi-Detached          Flat  2021-02-01         2  EDINBURGH

# %%
#TODO
